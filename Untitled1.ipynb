# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM

# %%
df = pd.read_csv(r'/content/drive/My Drive/Manasa_ML/combined file.csv')
df.head()
# Out:
#    1      2      3      4      5  ...    266    267    268    269    270
# 0  1  36.75  36.80  37.10  37.45  ...  62.05  44.95  41.90  38.70  36.55
# 1  1  52.65  55.50  46.55  38.55  ...  57.40  57.70  55.35  52.05  50.10
# 2  1  43.50  44.00  28.10  11.00  ...  63.15  64.65  65.85  63.05  62.60
# 3  1  41.40  39.80  38.95  37.55  ...  48.85  49.70  49.55  57.85  55.40
# 4  1  68.40  67.95  69.85  69.05  ...  68.15  69.95  54.40  53.80  55.95
#
# [5 rows x 270 columns]

# %%
df.fillna(df.mean(), inplace=True)
X = df.drop(['1'],axis=1)
y=df.loc[:,'1']
X
# Out:
#            2       3        4       5  ...     267      268    269      270
# 0    36.7500  36.800  37.1000  37.450  ...  44.950  41.9000  38.70  36.5500
# 1    52.6500  55.500  46.5500  38.550  ...  57.700  55.3500  52.05  50.1000
# 2    43.5000  44.000  28.1000  11.000  ...  64.650  65.8500  63.05  62.6000
# 3    41.4000  39.800  38.9500  37.550  ...  49.700  49.5500  57.85  55.4000
# 4    68.4000  67.950  69.8500  69.050  ...  69.950  54.4000  53.80  55.9500
# ..       ...     ...      ...     ...  ...     ...      ...    ...      ...
# 96   66.4000  66.800  67.9000  69.200  ...  68.500  70.0000  68.85  70.3000
# 97   67.2500  69.700  71.6000  68.850  ...  52.900  51.8000  49.80  57.9500
# 98   75.3500  75.600  76.4000  74.700  ...  72.700  73.4000  73.15  70.8500
# 99   74.8500  74.000  73.1500  76.450  ...  62.450  64.8000  67.95  68.7500
# 100  54.6435  54.988  54.8995  54.375  ...  48.368  48.4925  48.89  49.3115
#
# [101 rows x 269 columns]

# %%
row = X.iloc[0]
row.plot(kind='line')
row = X.iloc[1]
row.plot(kind='line')
row = X.iloc[10]
row.plot(kind='line')
row = X.iloc[20]
row.plot(kind='line')
plt.legend(loc='best')

# %%
df1 = X.sample(n = 20).T
df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')

# %%
X_1 = X.iloc[:25,:]
df1 = X_1.sample(n = 4).T
df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')

# %%
X_2 = X.iloc[25:50,:]
df1 = X_0.sample(n = 4).T
df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-faef2b590422> in <module>()
#       1 X_2 = X.iloc[25:50,:]
# ----> 2 df1 = X_0.sample(n = 4).T
#       3 df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')
#
# NameError: name 'X_0' is not defined

# %%
X_3 = X.iloc[50:75,:]
df1 = X_3.sample(n = 4).T
df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')

# %%
X_4 = X.iloc[75:100,:]
df1 = X_4.sample(n = 4).T
df1.plot(subplots=True, figsize=(20,12)); plt.legend(loc='best')

# %%
trainX , testX , trainy , testy = train_test_split(X,y,random_state=16)
