# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv(r'/content/drive/My Drive/Manasa_ML/combined file.csv')
df.head()
# Out:
#    1      2      3      4      5  ...    266    267    268    269    270
# 0  1  36.75  36.80  37.10  37.45  ...  62.05  44.95  41.90  38.70  36.55
# 1  1  52.65  55.50  46.55  38.55  ...  57.40  57.70  55.35  52.05  50.10
# 2  1  43.50  44.00  28.10  11.00  ...  63.15  64.65  65.85  63.05  62.60
# 3  1  41.40  39.80  38.95  37.55  ...  48.85  49.70  49.55  57.85  55.40
# 4  1  68.40  67.95  69.85  69.05  ...  68.15  69.95  54.40  53.80  55.95
#
# [5 rows x 270 columns]

# %%
len(df)
# Out:
# 101

# %%
df.describe()
# Out:
#                 2           3           4  ...         268         269         270
# count  100.000000  100.000000  100.000000  ...  100.000000  100.000000  100.000000
# mean    54.643500   54.988000   54.899500  ...   48.492500   48.890000   49.311500
# std     24.298326   24.190507   25.044597  ...   30.418179   29.543956   28.178322
# min    -42.650000  -42.650000  -56.650000  ... -167.150000 -156.350000 -134.350000
# 25%     48.450000   48.575000   47.737500  ...   41.612500   41.862500   42.650000
# 50%     61.900000   62.450000   62.875000  ...   57.350000   58.250000   57.450000
# 75%     68.475000   68.650000   69.362500  ...   64.912500   65.000000   64.425000
# max     86.400000   83.050000   84.400000  ...   81.250000   82.400000   83.950000
#
# [8 rows x 269 columns]

# %%
df.columns[df.isna().any()].tolist()

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.columns[df.isna().any()].tolist()
# Out:
# []

# %%
X = df.drop(['1'],axis=1) 
y=df.loc[:,'1']

X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=16)
model = KNeighborsClassifier(n_neighbors=10 )
model.fit(X_train,y_train)
ypred = model.predict(X_test)

# %%
print(classification_report(y_test, ypred))
print(accuracy_score(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.17      0.50      0.25         4
#            2       0.43      0.30      0.35        10
#            3       0.40      0.33      0.36         6
#            4       0.50      0.17      0.25         6
#
#     accuracy                           0.31        26
#    macro avg       0.37      0.33      0.30        26
# weighted avg       0.40      0.31      0.32        26
#
# 0.3076923076923077

# %%
import matplotlib.pyplot as plt
X_train[X_train.dtypes[(X_train.dtypes=="float64")|(X_train.dtypes=="int64")]
                        .index.values].hist(figsize=[11,11])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d6f6431a72f5> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 X_train[X_train.dtypes[(X_train.dtypes=="float64")|(X_train.dtypes=="int64")]
#       3                         .index.values].hist(figsize=[11,11])
#
# NameError: name 'X_train' is not defined

# %%
# Importing MinMaxScaler and initializing it
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
# Scaling down both train and test data set
X_train_minmax=min_max.fit_transform(X_train)
X_test_minmax=min_max.fit_transform(X_test)

# %%
model = KNeighborsClassifier(n_neighbors=10 )
model.fit(X_train_minmax,y_train)
ypred = model.predict(X_test_minmax)
print(classification_report(y_test, ypred))
print(accuracy_score(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.18      0.50      0.27         4
#            2       1.00      0.20      0.33        10
#            3       0.11      0.17      0.13         6
#            4       0.50      0.33      0.40         6
#
#     accuracy                           0.27        26
#    macro avg       0.45      0.30      0.28        26
# weighted avg       0.55      0.27      0.29        26
#
# 0.2692307692307692

# %%
from sklearn import preprocessing
X_train_normalized = preprocessing.normalize(X_train, norm='l2')
X_test_normalized = preprocessing.normalize(X_test, norm='l2')

# %%
model = KNeighborsClassifier(n_neighbors=10 )
model.fit(X_train_normalized,y_train)
ypred = model.predict(X_test_normalized)
print(classification_report(y_test, ypred))
print(accuracy_score(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.12      0.50      0.20         4
#            2       0.00      0.00      0.00        10
#            3       0.17      0.17      0.17         6
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.12        26
#    macro avg       0.07      0.17      0.09        26
# weighted avg       0.06      0.12      0.07        26
#
# 0.11538461538461539
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import preprocessing
X_train_normalized1 = preprocessing.normalize(X_train_minmax, norm='l2')
X_test_normalized1 = preprocessing.normalize(X_test_minmax, norm='l2')
model = KNeighborsClassifier(n_neighbors=10 )
model.fit(X_train_normalized1,y_train)
ypred = model.predict(X_test_normalized1)
print(classification_report(y_test, ypred))
print(accuracy_score(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.09      0.25      0.13         4
#            2       0.33      0.10      0.15        10
#            3       0.18      0.33      0.24         6
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.15        26
#    macro avg       0.15      0.17      0.13        26
# weighted avg       0.18      0.15      0.13        26
#
# 0.15384615384615385

# %%
from sklearn import tree, ensemble
cart = tree.DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=5)
cart.fit(X_train_normalized, y_train)
#predicting the result
y_pred1 = cart.predict(X_test_normalized)
print(classification_report(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))

cart = tree.DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=5)
cart.fit(X_train_normalized1, y_train)
#predicting the result
y_pred1 = cart.predict(X_test_normalized1)
print(classification_report(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))


cart = tree.DecisionTreeClassifier(criterion='entropy', max_depth=8, min_samples_leaf=5)
cart.fit(X_train, y_train)
#predicting the result
y_pred1 = cart.predict(X_test)
print(classification_report(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.40      0.50      0.44         4
#            2       0.57      0.40      0.47        10
#            3       0.25      0.17      0.20         6
#            4       0.30      0.50      0.37         6
#
#     accuracy                           0.38        26
#    macro avg       0.38      0.39      0.37        26
# weighted avg       0.41      0.38      0.38        26
#
# 0.38461538461538464
#               precision    recall  f1-score   support
#
#            1       0.50      0.25      0.33         4
#            2       0.25      0.10      0.14        10
#            3       0.00      0.00      0.00         6
#            4       0.24      0.67      0.35         6
#
#     accuracy                           0.23        26
#    macro avg       0.25      0.25      0.21        26
# weighted avg       0.23      0.23      0.19        26
#
# 0.23076923076923078
# ...

# %%
df = pd.read_csv(r'/content/drive/My Drive/Manasa_ML/combined file.csv')
df.fillna(df.mean(), inplace=True)

# %%
correlated_features = set()
correlation_matrix = df.iloc[:,1:].corr()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
df.drop(labels=correlated_features, axis=1, inplace=True)

# %%
df.head()
# Out:
#    1      2     72     99    125    134    145    235   237    243
# 0  1  36.75  46.50  63.65  39.45  45.30  51.25  55.65  60.9  64.75
# 1  1  52.65  23.30  43.05  75.05  49.70  30.45  64.45  59.4  50.40
# 2  1  43.50  47.35  54.90  61.50  55.85  27.65  67.90  69.2  50.10
# 3  1  41.40  33.15  63.30  72.30  53.45  40.55  56.50  59.7  59.90
# 4  1  68.40  38.30  66.30  57.45  66.00  50.00  61.45  62.5  65.95

# %%
X = df.drop(['1'],axis=1) 
y=df.loc[:,'1']

X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=16)
model = KNeighborsClassifier(n_neighbors=10 )
model.fit(X_train,y_train)
ypred = model.predict(X_test)
print(classification_report(y_test, ypred))
print(accuracy_score(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.15      0.50      0.24         4
#            2       0.50      0.30      0.37        10
#            3       0.29      0.33      0.31         6
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.27        26
#    macro avg       0.23      0.28      0.23        26
# weighted avg       0.28      0.27      0.25        26
#
# 0.2692307692307692
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df = pd.read_csv(r'/content/drive/My Drive/Manasa_ML/combined file.csv')
df.fillna(df.mean(), inplace=True)

# %%
#Using Pearson Correlation
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor.iloc[:,0])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# 2     1.000000
# 3     0.978054
# 4     0.945759
# 5     0.912123
# 6     0.873985
# 7     0.819887
# 8     0.774362
# 9     0.729762
# 10    0.712707
# 11    0.692427
# 12    0.667327
# 13    0.637772
# 14    0.613110
# 15    0.597149
# 16    0.575049
# 17    0.518137
# 18    0.501308
# 28    0.511245
# 29    0.528484
# 30    0.523247
# 31    0.530210
# 32    0.529019
# 33    0.536543
# 34    0.519753
# 35    0.515262
# 36    0.514954
# 37    0.519931
# 38    0.509185
# 39    0.505043
# 40    0.506540
# 41    0.501573
# Name: 2, dtype: float64

# %%
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 7)
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(X_rfe,y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f104d96cfded> in <module>()
# ----> 1 model = LinearRegression()
#       2 #Initializing RFE model
#       3 rfe = RFE(model, 7)
#       4 #Transforming data using RFE
#       5 X_rfe = rfe.fit_transform(X,y)
#
# NameError: name 'LinearRegression' is not defined

# %%
from keras.preprocessing import sequence
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

from keras.optimizers import Adam
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
import pandas as pd
import numpy as np
import os
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dropout, SimpleRNN, Embedding, Reshape
from keras.utils import to_categorical
from keras import regularizers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras import backend as K
from keras import optimizers
import tensorflow as tf
from tensorflow.keras.optimizers import SGD, Adam, Adamax


# X_train , X_test , y_train , y_test = train_test_split(X_t,y_t,random_state=16)
X_train = np.reshape(X_n, (101,269,1))
y_t = y_t.astype(int)
y = to_categorical(y_t)
print('Building Model...')
model = Sequential()
model.add(LSTM(units=32, activation='relu', input_shape=(269,1)))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(0.01),
             metrics=['categorical_accuracy'])
history = model.fit(np.reshape(X_n, (101,269,1)), y, validation_split=0.3,epochs=100)
